# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import wandb
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score
from skmultilearn.problem_transform import LabelPowerset

# %%
class ActivationFunctions:

    @staticmethod
    def tanh(x):
        return np.tanh(x)

    @staticmethod
    def relu(x):
        return np.maximum(0, x)

    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))
    
    @staticmethod
    def softmax(z):
        exp_z = np.exp(z - np.max(z,axis=0))
        return exp_z / np.sum(exp_z,axis=0)
    
    @staticmethod
    def tanh_derivative(x):
        tanh_x = np.tanh(x)
        return 1.0 - tanh_x**2
    
    @staticmethod
    def relu_derivative(x):
        return np.where(x > 0, 1.0, 0.0)
    
    @staticmethod
    def ignore(x):
        return 0

    @staticmethod
    def sigmoid_derivative(x):
        sigmoid_x = 1.0 / (1.0 + np.exp(-x))
        return sigmoid_x * (1.0 - sigmoid_x)
    
    @staticmethod
    def softmax_derivative(z):
        s = ActivationFunctions.softmax(z).flatten()
        jacobian_m = np.diag(s)
        for i in range(len(jacobian_m)):
            for j in range(len(jacobian_m)):
                if i == j:
                    jacobian_m[i][j] = s[i] * (1-s[i])
                else:
                    jacobian_m[i][j] = -s[i]*s[j]
        return jacobian_m

# %% [markdown]
# <h3>Data Preprocessing</h3>

# %%
df = pd.read_csv('./WineQT.csv')

# %%
print(np.mean(df,axis=0))

# %%
# printing total number of labels
np.unique(df['quality'])

# %%
# extract the important meaningful attributes
attb_df = df[["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol"]]

# %%
attb_df.describe()

# %%
dict_label = df['quality'].value_counts()

# %%
# plot a bar graph
dict_label = dict(dict_label)
plt.bar(list(dict_label.keys()),list(dict_label.values()))
plt.title('Occurances of labels in Wine dataset')
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.show()

# %%
dataset = np.array(df)

np.random.shuffle(dataset)

"""
CHECK AGAIN BOOKMARK
"""

# Compute the correlation matrix using numpy
corr_matrix = np.corrcoef(dataset[:,:11], rowvar=False)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
X = dataset[:,:11]
y = dataset[:,11]

# standardize
# calc z score for each entry columnwise
X = (X - np.mean(X,axis=0))/np.std(X,axis=0)

# %%
X.shape

# %%
# lets keep the split as train : 0.7, val : 0.1, test : 0.2
train_ratio = 0.65
val_ratio = 0.15
test_ratio = 0.20

# %%
entries = dataset.shape[0]

train_X = X[:int(train_ratio*entries)]
val_X = X[int(train_ratio*entries):int((train_ratio+val_ratio)*entries)]
test_X = X[int((train_ratio+val_ratio)*entries):]

# %%
train_y = y[:int(train_ratio*entries)]
val_y = y[int(train_ratio*entries):int((train_ratio+val_ratio)*entries)]
test_y = y[int((train_ratio+val_ratio)*entries):]

# %%
train_X.shape

# %%
val_y.shape

# %%
train_y.shape

# %%
train_y = train_y.reshape((-1,1))

# %% [markdown]
# <br>

# %% [markdown]
# <h3>Model training and WandB tuning</h3>

# %%
print(np.unique(train_y))

# %%
class MLP(ActivationFunctions):
  def __init__(self,input_dim,hidden_output_layer,optimizer='sgd',ep=5000,run_name="run"):
    
    self.weights = []
    self.biases=  []
    self.activation_func = []
    self.lr = 0.2
    self.ep = ep
    self.activation_func_name = []
    self.mode=0
    self.optimizer = optimizer

    self.derivatives = {
        'tanh': self.tanh_derivative,
        'relu': self.relu_derivative,
        'sigmoid': self.sigmoid_derivative,
        'softmax' : self.softmax_derivative,
        'none': self.ignore
      }
    
    #wandb
    wandb.init(project="mlp-2", config={
        "lr" : self.lr,
        "epochs" : ep
    })
    wandb.run.name = run_name

    # get all the activation functions
    self.activation_func_name.append('none')
    self.activation_func.append(0)

    for layer in hidden_output_layer:
      self.activation_func.append(getattr(self, layer[1]))
      self.activation_func_name.append(layer[1])

    # intialize eights and biases
    self.accumulator_grad_wts = []
    self.accumulator_grad_biases = []

    self.biases.append(np.zeros((input_dim,1)))
    self.accumulator_grad_biases.append(np.zeros((input_dim,1)))

    for i in range(len(hidden_output_layer)):
      l_layer = hidden_output_layer[i][0]

      if i!=0:
        prev_layer = hidden_output_layer[i-1][0]
      else:
        prev_layer = input_dim

      self.accumulator_grad_wts.append(np.zeros((l_layer,prev_layer)))
      self.accumulator_grad_biases.append(np.zeros((hidden_output_layer[i][0],1)))
      
      self.weights.append(np.random.rand(l_layer,prev_layer))
      self.biases.append(np.random.rand(hidden_output_layer[i][0],1))

    self.unactivated_outputs = []
    self.activated_outputs = []
  
  def cross_entropy_loss(self,y,yHat):
    J = -(np.sum(y * np.log(yHat)))/y.shape[0]
    return J

  def forwardProp(self,X):

    curr_output = X
    self.unactivated_outputs.append(X)
    self.activated_outputs.append(X)

    for l in range(1,len(self.weights)+1):
      z_l = self.weights[l-1] @ curr_output + self.biases[l]
      
      if self.mode==0:
          self.unactivated_outputs.append(z_l)
        
      output = self.activation_func[l](z_l)
    
      if self.mode==0:
          self.activated_outputs.append(output)

      curr_output = output
    
    curr_output = self.softmax(curr_output)

    return curr_output

  def backwardProp(self,X,y_prediction,y,sample_id,batch_size=None):

    n = len(self.activated_outputs)
    last_lay_unacout = self.unactivated_outputs[n-1]
    delta_l = (y_prediction-y)*(self.derivatives[self.activation_func_name[n-1]](last_lay_unacout))

    for i in range(n-1,0,-1):

      if self.optimizer=="sgd":
        self.weights[i-1] -= self.lr*(delta_l @ self.activated_outputs[i-1].T)
        self.biases[i] -= self.lr*(delta_l)
      
      else:
        self.accumulator_grad_wts[i-1] += delta_l @ self.activated_outputs[i-1].T
        self.accumulator_grad_biases[i] += delta_l

        if (sample_id+1)%batch_size==0:
          self.weights[i-1]-=self.lr*self.accumulator_grad_wts[i-1]
          self.biases[i]-=self.lr*self.accumulator_grad_biases[i]

      sigma_prime_zl = self.derivatives[self.activation_func_name[i-1]](self.unactivated_outputs[i-1])
      delta_l = (self.weights[i-1].T @ delta_l)*sigma_prime_zl
    
    
    self.activated_outputs.clear()
    self.unactivated_outputs.clear()

    
  def eval(self):
    self.mode=1

  def train(self):
    self.mode=0

  def fit(self,X,y,X_val, y_val):
    
    for epoch in range(self.ep):
      loss = 0
      train_acc = 0
      
      self.train()
      for sample_id in range(X.shape[0]):
        y_prediction = self.forwardProp(X[sample_id].reshape((-1,1)))
        if self.optimizer=="bgd":
          self.backwardProp(X[sample_id].reshape((-1,1)),y_prediction,y[sample_id].reshape((-1,1)),sample_id,batch_size=X.shape[0])
        
        else:
         batch_size = 64
         self.backwardProp(X[sample_id].reshape((-1,1)),y_prediction,y[sample_id].reshape((-1,1)),sample_id,batch_size=batch_size)

        loss += self.cross_entropy_loss(y[sample_id].reshape((-1,1)),y_prediction)
        comp_pred = np.argmax(y_prediction,axis=0)
        comp_act = np.argmax(y[sample_id],axis=0)
        train_acc+=(comp_pred==comp_act)
      
      train_acc = train_acc.item()/len(X)
      loss = loss/len(X)
      
      val_acc = 0
      val_loss = 0
    
      self.eval()
      # validation
      for idx in range(X_val.shape[0]):
            y_pred = self.forwardProp(X_val[idx].reshape((-1,1)))
            val_loss += self.cross_entropy_loss(y_val[idx].reshape((-1,1)),y_pred)
            comp_pred = np.argmax(y_pred,axis=0)
            comp_act = np.argmax(y_val[idx],axis=0)
            val_acc+=(comp_pred==comp_act)
      val_acc = val_acc.item()/len(X_val)
      val_loss = val_loss/len(X_val)

      self.activated_outputs.clear()
      self.unactivated_outputs.clear()
        
      wandb.log({"train_accuracy": train_acc,"train_loss": loss,"val_accuracy": val_acc , "val_loss" : val_loss})
      print(f"Epoch {epoch}, training_accuracy : {train_acc} training_loss : {loss} val_accuracy : {val_acc} val_loss : {val_loss}")

# %%
import wandb

# mlp = MLP(11,[(8,'sigmoid'),(8,'sigmoid'),(6,'sigmoid')],optimizer='sgd')

train_y = train_y.reshape((-1,1))
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_true = one_hot_encoder.fit_transform(train_y)

val_y = val_y.reshape((-1,1))
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_true_val = one_hot_encoder.fit_transform(val_y)

y_true_val.shape

# %%
mlp = MLP(11,[(9,'sigmoid'),(7,'sigmoid'),(6,'sigmoid')],optimizer='sgd')
mlp.fit(train_X,y_true,val_X,y_true_val)

# %% [markdown]
# <h3>Accuracy on Test Set</h3>

# %%
test_y = test_y.reshape((-1,1))
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_true_test = one_hot_encoder.fit_transform(test_y)

y_pr_arr = []
y_act = []

test_acc = 0
for idx in range(test_X.shape[0]):
      y_pred = mlp.forwardProp(test_X[idx].reshape((-1,1)))
      
      comp_pred = np.argmax(y_pred,axis=0)
      comp_act = np.argmax(y_true_test[idx],axis=0)
      y_pr_arr.append(comp_pred)
      y_act.append(comp_act)
      
      test_acc+=(comp_pred==comp_act)
test_acc = test_acc.item()/len(test_X)
print("Test accuracy : ",test_acc)

# %%
wandb.finish()

# %% [markdown]
# ### Classification Report on Test Set

# %%
y = y_act
y_pred = y_pr_arr

# Classification Report
print("Classification Report:")
print(classification_report(y, y_pred))

# Other metrics
accuracy = accuracy_score(y, y_pred)
precision = precision_score(y, y_pred,average='weighted')
recall = recall_score(y, y_pred,average='weighted')
f1 = f1_score(y, y_pred,average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# %% [markdown]
# ### Combinations of activation function and optimizers

# %%
for activn_funcn in ['sigmoid','relu','tanh']:
    for optim in ['sgd','bgd','mbgd']:
        model = MLP(11,[(9,activn_funcn),(7,activn_funcn),(6,activn_funcn)],optimizer=optim,ep=200,run_name=f"{activn_funcn}+{optim}")
        model.fit(train_X,y_true,val_X,y_true_val)

# %%
model = MLP(11,[(9,'relu'),(7,'relu'),(6,'relu')],optimizer='sgd',ep=200,run_name=f"trial")
model.fit(train_X,y_true,val_X,y_true_val)

# %% [markdown]
# ### Multilabel classification

# %%
df = pd.read_csv('./advertisement.csv')

# %%
np_ds = np.array(df)

# %%
unique_labels  = set()

for arr in np_ds:
    lbl_str = arr[-1].split(' ')
    for lbl in lbl_str:
        unique_labels.add(lbl)

print(unique_labels)

# %%
df[df["gender"]=="Female"].head(50)

# %%
female_df = df[df["gender"]=="Female"]

# %%
np_ds_female = np.array(female_df)

map_labels1 = {}

for arr in np_ds_female:
    lbl_str = arr[-1].split(' ')
    for lbl in lbl_str:
        try:
            map_labels1[lbl]+=1
        except:
            map_labels1[lbl]=1

print(map_labels1)

# %%
np_ds_female.shape

# %%
print(sum(list(map_labels1.values())))

# %%
male_df = df[df["gender"]=="Male"]

# %%
np_ds_male = np.array(male_df)

map_labels2 = {}

for arr in np_ds_male:
    lbl_str = arr[-1].split(' ')
    for lbl in lbl_str:
        try:
            map_labels2[lbl]+=1
        except:
            map_labels2[lbl]=1

print(map_labels2)

# %%
# Find common keys
common_keys = set(map_labels1.keys()) & set(map_labels2.keys())

# Prepare data for plotting
values1 = [map_labels1[key] for key in common_keys]
values2 = [map_labels2[key] for key in common_keys]

# Plotting
import matplotlib.pyplot as plt
import numpy as np

# Setting up the x-axis positions
x = np.arange(len(common_keys))

# Setting up the width for bars
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, values1, width, label='female')
rects2 = ax.bar(x + width/2, values2, width, label='male')

# Adding labels, title, and legend
ax.set_ylabel('Values')
ax.set_title('Comparison between values of common keys in Map Labels 1 and Map Labels 2')
ax.set_xticks(x)
ax.set_xticklabels(common_keys)
ax.legend()

fig.tight_layout()
plt.show()

# %%
# Splitting  the train val test split
# keeping the ration 70 : 15 : 15
test = 0.10
val = 0.15
train = 0.80

df = pd.read_csv('./advertisement.csv')
data = np.array(df)

# %%
"""
We can see column : 1,3,4,6,7,9 are categorical , hence need to be encoded.
"""

for column in [1,3,4,6,7,9]:
    label_encode = LabelEncoder()
    encoded_feature = label_encode.fit_transform(data[:,column])
    data[:,column] = encoded_feature

# %%
print(data.shape)

# %%
print(data[:,:-1])

# %%
my_featur_sample = data[:,:-1].copy() 
my_featur_sample  = my_featur_sample.astype(np.float64)

# %%
my_featur_sample = (my_featur_sample - np.mean(my_featur_sample,axis=0))/(np.std(my_featur_sample,axis=0))

# %%
np.std(np.array([[1],[2],[3]]),axis=1)

# %%
print(data[0])

# %%
data[:,:-1] = my_featur_sample

# %%
label_encode_mlb = MultiLabelBinarizer()

formatted_list = []

for lbl_string in data[:,-1]:
    formatted_list.append(lbl_string.split(' '))
    
encoded_labels = label_encode_mlb.fit_transform(formatted_list)
    
train_x,train_y = data[:int(train*data.shape[0]),:-1],encoded_labels[:int(train*data.shape[0])]
val_x,val_y = data[int(train*data.shape[0]):int(train*data.shape[0])+int(val*data.shape[0]),:-1],encoded_labels[int(train*data.shape[0]):int(train*data.shape[0])+int(val*data.shape[0])]
test_x,test_y = data[int(train*data.shape[0])+int(val*data.shape[0]):int(train*data.shape[0])+int(val*data.shape[0])+int(test*data.shape[0]),:-1],encoded_labels[int(train*data.shape[0])+int(val*data.shape[0]):int(train*data.shape[0])+int(val*data.shape[0])+int(test*data.shape[0])]

print(train_x.shape,train_y.shape)
print(test_x.shape,test_y.shape)
print(val_x.shape,val_y.shape)

# %%
label_encode.classes_

# %%
print(train_y.shape)
print(train_x.shape)

# %%
print(train_x)

# %%
class ActivationFunctions:

    @staticmethod
    def tanh(x):
        return np.tanh(x)

    @staticmethod
    def relu(x):
        return np.maximum(0, x)

    @staticmethod
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))
    
    @staticmethod
    def softmax(z):
        exp_z = np.exp(z - np.max(z,axis=0))
        return exp_z / np.sum(exp_z,axis=0)
    
    @staticmethod
    def tanh_derivative(x):
        tanh_x = np.tanh(x)
        return 1.0 - tanh_x**2
    
    @staticmethod
    def relu_derivative(x):
        return np.where(x > 0, 1.0, 0.0)
    
    @staticmethod
    def ignore(x):
        return 0

    @staticmethod
    def sigmoid_derivative(x):
        sigmoid_x = 1.0 / (1.0 + np.exp(-x))
        return sigmoid_x * (1.0 - sigmoid_x)
    
    @staticmethod
    def softmax_derivative(z):
        s = ActivationFunctions.softmax(z).flatten()
        jacobian_m = np.diag(s)
        for i in range(len(jacobian_m)):
            for j in range(len(jacobian_m)):
                if i == j:
                    jacobian_m[i][j] = s[i] * (1-s[i])
                else:
                    jacobian_m[i][j] = -s[i]*s[j]
        return jacobian_m

# %%
class MLP(ActivationFunctions):
  def __init__(self,input_dim,hidden_output_layer,optimizer='sgd',ep=50,run_name="run"):
    
    self.weights = []
    self.biases=  []
    self.activation_func = []
    self.lr = 0.1
    self.ep = ep
    self.activation_func_name = []
    self.mode=0
    self.optimizer = optimizer

    self.derivatives = {
        'tanh': self.tanh_derivative,
        'relu': self.relu_derivative,
        'sigmoid': self.sigmoid_derivative,
        'softmax' : self.softmax_derivative,
        'none': self.ignore
      }
    
    #wandb
    # wandb.init(project="mlp-2", config={
    #     "lr" : self.lr,
    #     "epochs" : ep
    # })
    # wandb.run.name = run_name

    # get all the activation functions
    self.activation_func_name.append('none')
    self.activation_func.append(0)

    for layer in hidden_output_layer:
      self.activation_func.append(getattr(self, layer[1]))
      self.activation_func_name.append(layer[1])

    # intialize eights and biases
    self.accumulator_grad_wts = []
    self.accumulator_grad_biases = []

    self.biases.append(np.zeros((input_dim,1)))
    self.accumulator_grad_biases.append(np.zeros((input_dim,1)))

    for i in range(len(hidden_output_layer)):
      l_layer = hidden_output_layer[i][0]

      if i!=0:
        prev_layer = hidden_output_layer[i-1][0]
      else:
        prev_layer = input_dim

      self.accumulator_grad_wts.append(np.zeros((l_layer,prev_layer)))
      self.accumulator_grad_biases.append(np.zeros((hidden_output_layer[i][0],1)))
      
      self.weights.append(np.random.rand(l_layer,prev_layer))
      self.biases.append(np.random.rand(hidden_output_layer[i][0],1))

    self.unactivated_outputs = []
    self.activated_outputs = []
  
  def binary_cross_entropy_loss(self,y,yHat):
    J = -(np.sum(y * np.log(yHat) + (1-y)*np.log(1-yHat)))/y.shape[0]
    return J

  def forwardProp(self,X):

    curr_output = X
    self.unactivated_outputs.append(X)
    self.activated_outputs.append(X)

    # print(X.shape)
    for l in range(1,len(self.weights)+1):
      z_l = self.weights[l-1] @ curr_output + self.biases[l]
      
      if self.mode==0:
          self.unactivated_outputs.append(z_l)
      
      output = self.activation_func[l](z_l)
    
      if self.mode==0:
          self.activated_outputs.append(output)

      curr_output = output
    
    # curr_output = self.softmax(curr_output)

    return curr_output

  def backwardProp(self,X,y_prediction,y,sample_id,batch_size=None):

    n = len(self.activated_outputs)
    last_lay_unacout = self.unactivated_outputs[n-1]
    delta_l = (y_prediction-y)*(self.derivatives[self.activation_func_name[n-1]](last_lay_unacout))

    for i in range(n-1,0,-1):

      if self.optimizer=="sgd":
        self.weights[i-1] -= self.lr*(delta_l @ self.activated_outputs[i-1].T)
        self.biases[i] -= self.lr*(delta_l)
      
      else:
        self.accumulator_grad_wts[i-1] += delta_l @ self.activated_outputs[i-1].T
        self.accumulator_grad_biases[i] += delta_l

        if (sample_id+1)%batch_size==0:
          self.weights[i-1]-=self.lr*self.accumulator_grad_wts[i-1]
          self.biases[i]-=self.lr*self.accumulator_grad_biases[i]

      sigma_prime_zl = self.derivatives[self.activation_func_name[i-1]](self.unactivated_outputs[i-1])
      delta_l = (self.weights[i-1].T @ delta_l)*sigma_prime_zl
    
    
    self.activated_outputs.clear()
    self.unactivated_outputs.clear()

    
  def eval(self):
    self.mode=1

  def train(self):
    self.mode=0

  def multilabel_accuracy(self,y_true, y_pred, threshold=0.5):
    
    # print(y_true.shape,y_pred.shape)
    # Convert predictions to 1 or 0 based on threshold
    y_pred_thresholded = (y_pred > threshold).astype(int)
    # print(y_pred_thresholded,y_pred)
    
    # Check if the predicted labels match the true labels
    correct_predictions = (y_true == y_pred_thresholded).astype(int)
    
    # Compute accuracy for each label and then take the mean
    if len(y_pred) == correct_predictions.sum():
      return 1
    
    return 0

  def fit(self,X,y,X_val, y_val):
    
    for epoch in range(self.ep):
      loss = 0
      train_acc = 0
      
      self.train()
      for sample_id in range(X.shape[0]):
        y_prediction = self.forwardProp(X[sample_id].reshape((-1,1)))

        if self.optimizer=="bgd":
          self.backwardProp(X[sample_id].reshape((-1,1)),y_prediction,y[sample_id].reshape((-1,1)),sample_id,batch_size=X.shape[0])
        
        else:
         batch_size = 64
         self.backwardProp(X[sample_id].reshape((-1,1)),y_prediction,y[sample_id].reshape((-1,1)),sample_id,batch_size=batch_size)

        loss += self.binary_cross_entropy_loss(y[sample_id].reshape((-1,1)),y_prediction)
        # comp_pred = np.argmax(y_prediction,axis=0)
        # comp_act = np.argmax(y[sample_id],axis=0)
        # print(y_prediction.shape)
        train_acc+=self.multilabel_accuracy(y[sample_id].reshape((-1,1)),y_prediction)
      
      train_acc = train_acc/len(X)
      loss = loss/len(X)
      
      val_acc = 0
      val_loss = 0
    
      self.eval()
      # validation
      for idx in range(X_val.shape[0]):
            y_pred = self.forwardProp(X_val[idx].reshape((-1,1)))
            # print(y_pred.shape,y_val[idx].reshape((-1,1)).shape)
            val_loss += self.binary_cross_entropy_loss(y_val[idx].reshape((-1,1)),y_pred)
            # comp_pred = np.argmax(y_pred,axis=0)
            # comp_act = np.argmax(y_val[idx],axis=0)
            val_acc+=self.multilabel_accuracy(y_val[idx].reshape((-1,1)),y_pred)
      val_acc = val_acc/len(X_val)
      val_loss = val_loss/len(X_val)

      self.activated_outputs.clear()
      self.unactivated_outputs.clear()
        
      # wandb.log({"train_accuracy": train_acc,"train_loss": loss,"val_accuracy": val_acc , "val_loss" : val_loss})
      print(f"Epoch {epoch}, training_accuracy : {train_acc} training_loss : {loss} val_accuracy : {val_acc} val_loss : {val_loss}")

# %%
ActivationFunctions.sigmoid(np.array([[1.555],[2.333],[3.77]]))
# Out:
# array([[0.82563471],
#        [0.91157346],
#        [0.97746736]])

# %%
import wandb
model = MLP(10,[(6,'sigmoid'),(6,'sigmoid'),(8,'sigmoid')],optimizer='sgd',ep=5000,run_name=f"multilabel")
model.fit(train_x.astype(np.float64),train_y.astype(np.float64),val_x.astype(np.float64),val_y.astype(np.float64))
# Out:
# Epoch 0, training_accuracy : 0.00125 training_loss : 0.7499206473287562 val_accuracy : 0.0 val_loss : 0.6548931963306939
# Epoch 1, training_accuracy : 0.0 training_loss : 0.6530588199076521 val_accuracy : 0.0 val_loss : 0.6548730154632316
# Epoch 2, training_accuracy : 0.0 training_loss : 0.6529251140355268 val_accuracy : 0.0 val_loss : 0.6548406444298392
# Epoch 3, training_accuracy : 0.0 training_loss : 0.6527874733645114 val_accuracy : 0.0 val_loss : 0.6547801745874343
# Epoch 4, training_accuracy : 0.0 training_loss : 0.6526229656882334 val_accuracy : 0.0 val_loss : 0.6546740263684622
# Epoch 5, training_accuracy : 0.0 training_loss : 0.6524060666292306 val_accuracy : 0.0 val_loss : 0.6544978190469273
# Epoch 6, training_accuracy : 0.0 training_loss : 0.6521022928157909 val_accuracy : 0.0 val_loss : 0.6542133504787645
# Epoch 7, training_accuracy : 0.0 training_loss : 0.6516600115320553 val_accuracy : 0.0 val_loss : 0.6537583270767794
# Epoch 8, training_accuracy : 0.0 training_loss : 0.6510014195906847 val_accuracy : 0.0 val_loss : 0.6530362987464089
# Epoch 9, training_accuracy : 0.0 training_loss : 0.6500247919170445 val_accuracy : 0.0 val_loss : 0.651932230232055
# Epoch 10, training_accuracy : 0.0 training_loss : 0.6486567836416153 val_accuracy : 0.0 val_loss : 0.6504209120475009
# Epoch 11, training_accuracy : 0.0 training_loss : 0.6469848446084708 val_accuracy : 0.0 val_loss : 0.6487581996694681
# Epoch 12, training_accuracy : 0.0025 training_loss : 0.6453293679585239 val_accuracy : 0.0 val_loss : 0.647421333940786
# Epoch 13, training_accuracy : 0.00625 training_loss : 0.6440368008252497 val_accuracy : 0.0 val_loss : 0.6466789219233927
# Epoch 14, training_accuracy : 0.0125 training_loss : 0.6432107445251901 val_accuracy : 0.0 val_loss : 0.6464341342291409
# Epoch 15, training_accuracy : 0.0125 training_loss : 0.6427391189385571 val_accuracy : 0.0 val_loss : 0.646471982999669
# Epoch 16, training_accuracy : 0.0175 training_loss : 0.6424722954446699 val_accuracy : 0.0 val_loss : 0.6466364779709974
# Epoch 17, training_accuracy : 0.0175 training_loss : 0.6423093086062742 val_accuracy : 0.0 val_loss : 0.6468453798125172
# Epoch 18, training_accuracy : 0.0175 training_loss : 0.6421974394333222 val_accuracy : 0.0 val_loss : 0.647060087380359
# Epoch 19, training_accuracy : 0.0175 training_loss : 0.6421120844509379 val_accuracy : 0.0 val_loss : 0.6472632646917108
# Epoch 20, training_accuracy : 0.02 training_loss : 0.6420419376519918 val_accuracy : 0.0 val_loss : 0.6474477790348555
# Epoch 21, training_accuracy : 0.0225 training_loss : 0.6419813219776564 val_accuracy : 0.0 val_loss : 0.6476116550795274
# Epoch 22, training_accuracy : 0.02125 training_loss : 0.6419269136421191 val_accuracy : 0.0 val_loss : 0.6477556126172417
# Epoch 23, training_accuracy : 0.02125 training_loss : 0.641876541156298 val_accuracy : 0.0 val_loss : 0.6478817268861538
# Epoch 24, training_accuracy : 0.02125 training_loss : 0.6418287669482656 val_accuracy : 0.0 val_loss : 0.6479926274367703
# Epoch 25, training_accuracy : 0.02125 training_loss : 0.6417826865863511 val_accuracy : 0.0 val_loss : 0.648090988754848
# Epoch 26, training_accuracy : 0.02 training_loss : 0.6417377608245022 val_accuracy : 0.0 val_loss : 0.648179215281098
# Epoch 27, training_accuracy : 0.0175 training_loss : 0.6416936570136109 val_accuracy : 0.0 val_loss : 0.6482592856929824
# Epoch 28, training_accuracy : 0.0175 training_loss : 0.6416501249126176 val_accuracy : 0.006666666666666667 val_loss : 0.6483327296961564
# Epoch 29, training_accuracy : 0.0175 training_loss : 0.6416069278208107 val_accuracy : 0.006666666666666667 val_loss : 0.6484006971612641
# Epoch 30, training_accuracy : 0.0175 training_loss : 0.641563829051598 val_accuracy : 0.006666666666666667 val_loss : 0.6484640706867094
# Epoch 31, training_accuracy : 0.0175 training_loss : 0.6415206170203274 val_accuracy : 0.006666666666666667 val_loss : 0.6485235776064506
# Epoch 32, training_accuracy : 0.0175 training_loss : 0.6414771465418825 val_accuracy : 0.006666666666666667 val_loss : 0.6485798711032018
# Epoch 33, training_accuracy : 0.0175 training_loss : 0.6414333763290719 val_accuracy : 0.006666666666666667 val_loss : 0.6486335652463321
# Epoch 34, training_accuracy : 0.0175 training_loss : 0.6413893880066585 val_accuracy : 0.006666666666666667 val_loss : 0.6486852228328451
# Epoch 35, training_accuracy : 0.0175 training_loss : 0.6413453781346632 val_accuracy : 0.006666666666666667 val_loss : 0.6487353080342302
# Epoch 36, training_accuracy : 0.0175 training_loss : 0.6413016224561471 val_accuracy : 0.006666666666666667 val_loss : 0.6487841263181331
# Epoch 37, training_accuracy : 0.0175 training_loss : 0.6412584207818485 val_accuracy : 0.006666666666666667 val_loss : 0.6488317773502457
# Epoch 38, training_accuracy : 0.01625 training_loss : 0.641216038411152 val_accuracy : 0.006666666666666667 val_loss : 0.6488781395650038
# Epoch 39, training_accuracy : 0.01625 training_loss : 0.6411746612225813 val_accuracy : 0.006666666666666667 val_loss : 0.648922891061636
# Epoch 40, training_accuracy : 0.01625 training_loss : 0.6411343751482889 val_accuracy : 0.006666666666666667 val_loss : 0.6489655585533591
# Epoch 41, training_accuracy : 0.01625 training_loss : 0.641095170521829 val_accuracy : 0.006666666666666667 val_loss : 0.6490055806163743
# Epoch 42, training_accuracy : 0.0175 training_loss : 0.6410569637379111 val_accuracy : 0.006666666666666667 val_loss : 0.649042373563202
# Epoch 43, training_accuracy : 0.0175 training_loss : 0.6410196260826067 val_accuracy : 0.006666666666666667 val_loss : 0.6490753935668042
# Epoch 44, training_accuracy : 0.0175 training_loss : 0.6409830116036662 val_accuracy : 0.006666666666666667 val_loss : 0.649104192929578
# Epoch 45, training_accuracy : 0.0175 training_loss : 0.6409469796160647 val_accuracy : 0.006666666666666667 val_loss : 0.6491284699088172
# Epoch 46, training_accuracy : 0.0175 training_loss : 0.6409114105890578 val_accuracy : 0.006666666666666667 val_loss : 0.649148110735825
# Epoch 47, training_accuracy : 0.0175 training_loss : 0.6408762159218295 val_accuracy : 0.006666666666666667 val_loss : 0.6491632207059225
# Epoch 48, training_accuracy : 0.0175 training_loss : 0.6408413426846079 val_accuracy : 0.006666666666666667 val_loss : 0.6491741397504361
# Epoch 49, training_accuracy : 0.0175 training_loss : 0.6408067743083123 val_accuracy : 0.006666666666666667 val_loss : 0.6491814376935898
# Epoch 50, training_accuracy : 0.01875 training_loss : 0.6407725279128512 val_accuracy : 0.006666666666666667 val_loss : 0.6491858860112448
# Epoch 51, training_accuracy : 0.01875 training_loss : 0.6407386487642518 val_accuracy : 0.006666666666666667 val_loss : 0.6491884063787502
# Epoch 52, training_accuracy : 0.01875 training_loss : 0.6407052023650043 val_accuracy : 0.006666666666666667 val_loss : 0.64919000096603
# Epoch 53, training_accuracy : 0.01875 training_loss : 0.6406722648875316 val_accuracy : 0.006666666666666667 val_loss : 0.6491916739586733
# Epoch 54, training_accuracy : 0.01875 training_loss : 0.6406399129282648 val_accuracy : 0.006666666666666667 val_loss : 0.6491943564627559
# Epoch 55, training_accuracy : 0.01875 training_loss : 0.6406082137194771 val_accuracy : 0.006666666666666667 val_loss : 0.6491988464943966
# Epoch 56, training_accuracy : 0.0175 training_loss : 0.6405772168642571 val_accuracy : 0.006666666666666667 val_loss : 0.649205772049001
# Epoch 57, training_accuracy : 0.0175 training_loss : 0.6405469483454825 val_accuracy : 0.006666666666666667 val_loss : 0.649215579594413
# Epoch 58, training_accuracy : 0.0175 training_loss : 0.6405174071044041 val_accuracy : 0.006666666666666667 val_loss : 0.6492285448354401
# Epoch 59, training_accuracy : 0.0175 training_loss : 0.640488564038777 val_accuracy : 0.006666666666666667 val_loss : 0.6492447990337974
# Epoch 60, training_accuracy : 0.0175 training_loss : 0.6404603629526173 val_accuracy : 0.006666666666666667 val_loss : 0.6492643631910604
# Epoch 61, training_accuracy : 0.0175 training_loss : 0.6404327228428063 val_accuracy : 0.006666666666666667 val_loss : 0.6492871835217847
# Epoch 62, training_accuracy : 0.0175 training_loss : 0.6404055409095349 val_accuracy : 0.006666666666666667 val_loss : 0.6493131638026807
# Epoch 63, training_accuracy : 0.0175 training_loss : 0.6403786957742414 val_accuracy : 0.006666666666666667 val_loss : 0.6493421923993119
# Epoch 64, training_accuracy : 0.0175 training_loss : 0.6403520505269139 val_accuracy : 0.006666666666666667 val_loss : 0.6493741634711763
# Epoch 65, training_accuracy : 0.0175 training_loss : 0.6403254553664524 val_accuracy : 0.006666666666666667 val_loss : 0.6494089928817438
# Epoch 66, training_accuracy : 0.0175 training_loss : 0.6402987497214159 val_accuracy : 0.006666666666666667 val_loss : 0.64944662979083
# Epoch 67, training_accuracy : 0.0175 training_loss : 0.6402717638349124 val_accuracy : 0.006666666666666667 val_loss : 0.6494870649724441
# Epoch 68, training_accuracy : 0.0175 training_loss : 0.6402443198649341 val_accuracy : 0.006666666666666667 val_loss : 0.6495303367589591
# Epoch 69, training_accuracy : 0.0175 training_loss : 0.6402162325932312 val_accuracy : 0.006666666666666667 val_loss : 0.6495765352867636
# Epoch 70, training_accuracy : 0.0175 training_loss : 0.6401873098566384 val_accuracy : 0.006666666666666667 val_loss : 0.6496258054810892
# Epoch 71, training_accuracy : 0.0175 training_loss : 0.640157352819721 val_accuracy : 0.006666666666666667 val_loss : 0.6496783490019453
# Epoch 72, training_accuracy : 0.0175 training_loss : 0.6401261562008006 val_accuracy : 0.006666666666666667 val_loss : 0.649734425192028
# Epoch 73, training_accuracy : 0.0175 training_loss : 0.6400935085465922 val_accuracy : 0.006666666666666667 val_loss : 0.6497943509270772
# Epoch 74, training_accuracy : 0.01875 training_loss : 0.6400591926240544 val_accuracy : 0.006666666666666667 val_loss : 0.6498584991775731
# Epoch 75, training_accuracy : 0.01875 training_loss : 0.6400229859605006 val_accuracy : 0.006666666666666667 val_loss : 0.6499272960617136
# Epoch 76, training_accuracy : 0.01875 training_loss : 0.6399846615148281 val_accuracy : 0.006666666666666667 val_loss : 0.650001216221889
# Epoch 77, training_accuracy : 0.01875 training_loss : 0.6399439884070102 val_accuracy : 0.006666666666666667 val_loss : 0.650080776506272
# Epoch 78, training_accuracy : 0.01875 training_loss : 0.6399007325796644 val_accuracy : 0.006666666666666667 val_loss : 0.6501665281853906
# Epoch 79, training_accuracy : 0.01875 training_loss : 0.6398546572321882 val_accuracy : 0.006666666666666667 val_loss : 0.6502590482530085
# Epoch 80, training_accuracy : 0.01875 training_loss : 0.6398055228807944 val_accuracy : 0.006666666666666667 val_loss : 0.6503589306825694
# Epoch 81, training_accuracy : 0.01875 training_loss : 0.6397530869878307 val_accuracy : 0.006666666666666667 val_loss : 0.6504667787247967
# Epoch 82, training_accuracy : 0.0175 training_loss : 0.6396971032997025 val_accuracy : 0.006666666666666667 val_loss : 0.6505831993068496
# Epoch 83, training_accuracy : 0.0175 training_loss : 0.6396373213490222 val_accuracy : 0.006666666666666667 val_loss : 0.6507088002148721
# Epoch 84, training_accuracy : 0.0175 training_loss : 0.6395734869991035 val_accuracy : 0.006666666666666667 val_loss : 0.6508441899638282
# Epoch 85, training_accuracy : 0.0175 training_loss : 0.6395053453813534 val_accuracy : 0.006666666666666667 val_loss : 0.6509899791382444
# Epoch 86, training_accuracy : 0.0175 training_loss : 0.6394326479883162 val_accuracy : 0.006666666666666667 val_loss : 0.6511467806870851
# Epoch 87, training_accuracy : 0.01625 training_loss : 0.6393551658675097 val_accuracy : 0.006666666666666667 val_loss : 0.6513152054116648
# Epoch 88, training_accuracy : 0.01625 training_loss : 0.639272710585945 val_accuracy : 0.006666666666666667 val_loss : 0.6514958479733605
# Epoch 89, training_accuracy : 0.01625 training_loss : 0.6391851636398339 val_accuracy : 0.006666666666666667 val_loss : 0.6516892584856304
# Epoch 90, training_accuracy : 0.0175 training_loss : 0.6390925130410746 val_accuracy : 0.006666666666666667 val_loss : 0.6518958955451976
# Epoch 91, training_accuracy : 0.0175 training_loss : 0.6389948928890014 val_accuracy : 0.006666666666666667 val_loss : 0.6521160589084979
# Epoch 92, training_accuracy : 0.0175 training_loss : 0.6388926182495244 val_accuracy : 0.006666666666666667 val_loss : 0.6523498044091046
# Epoch 93, training_accuracy : 0.0175 training_loss : 0.6387862047395975 val_accuracy : 0.006666666666666667 val_loss : 0.6525968501613064
# Epoch 94, training_accuracy : 0.0175 training_loss : 0.6386763616701476 val_accuracy : 0.006666666666666667 val_loss : 0.6528564904996288
# Epoch 95, training_accuracy : 0.0175 training_loss : 0.6385639512818306 val_accuracy : 0.006666666666666667 val_loss : 0.6531275397460825
# Epoch 96, training_accuracy : 0.0175 training_loss : 0.6384499150112635 val_accuracy : 0.006666666666666667 val_loss : 0.653408327943314
# Epoch 97, training_accuracy : 0.01875 training_loss : 0.6383351786499318 val_accuracy : 0.006666666666666667 val_loss : 0.6536967622285138
# Epoch 98, training_accuracy : 0.01875 training_loss : 0.6382205569683538 val_accuracy : 0.006666666666666667 val_loss : 0.653990451348015
# Epoch 99, training_accuracy : 0.01875 training_loss : 0.6381066801064899 val_accuracy : 0.006666666666666667 val_loss : 0.6542868726348587
# Epoch 100, training_accuracy : 0.02 training_loss : 0.6379939574131818 val_accuracy : 0.006666666666666667 val_loss : 0.654583548777018
# Epoch 101, training_accuracy : 0.02125 training_loss : 0.6378825828095298 val_accuracy : 0.013333333333333334 val_loss : 0.6548782015080283
# Epoch 102, training_accuracy : 0.02125 training_loss : 0.6377725748767861 val_accuracy : 0.013333333333333334 val_loss : 0.655168860315757
# Epoch 103, training_accuracy : 0.02125 training_loss : 0.637663838798661 val_accuracy : 0.013333333333333334 val_loss : 0.6554539202590466
# Epoch 104, training_accuracy : 0.02125 training_loss : 0.6375562362878562 val_accuracy : 0.013333333333333334 val_loss : 0.6557321566036015
# Epoch 105, training_accuracy : 0.0225 training_loss : 0.6374496512814811 val_accuracy : 0.013333333333333334 val_loss : 0.6560027106096504
# Epoch 106, training_accuracy : 0.0225 training_loss : 0.6373440411856858 val_accuracy : 0.013333333333333334 val_loss : 0.6562650600091424
# Epoch 107, training_accuracy : 0.0225 training_loss : 0.6372394655434832 val_accuracy : 0.013333333333333334 val_loss : 0.6565189823806242
# Epoch 108, training_accuracy : 0.0225 training_loss : 0.6371360877436142 val_accuracy : 0.013333333333333334 val_loss : 0.6567645140037386
# Epoch 109, training_accuracy : 0.0225 training_loss : 0.6370341518164113 val_accuracy : 0.013333333333333334 val_loss : 0.6570019042407051
# Epoch 110, training_accuracy : 0.0225 training_loss : 0.6369339436396791 val_accuracy : 0.013333333333333334 val_loss : 0.6572315666955604
# Epoch 111, training_accuracy : 0.0225 training_loss : 0.6368357498105798 val_accuracy : 0.013333333333333334 val_loss : 0.6574540310177265
# Epoch 112, training_accuracy : 0.0225 training_loss : 0.6367398252722447 val_accuracy : 0.013333333333333334 val_loss : 0.6576699001619581
# Epoch 113, training_accuracy : 0.02375 training_loss : 0.6366463742310569 val_accuracy : 0.013333333333333334 val_loss : 0.6578798161424161
# Epoch 114, training_accuracy : 0.025 training_loss : 0.6365555425604448 val_accuracy : 0.013333333333333334 val_loss : 0.6580844342911317
# Epoch 115, training_accuracy : 0.025 training_loss : 0.6364674170227386 val_accuracy : 0.013333333333333334 val_loss : 0.6582844038261129
# Epoch 116, training_accuracy : 0.025 training_loss : 0.636382027212551 val_accuracy : 0.013333333333333334 val_loss : 0.6584803520438186
# Epoch 117, training_accuracy : 0.02375 training_loss : 0.6362993481902995 val_accuracy : 0.013333333333333334 val_loss : 0.658672870239029
# Epoch 118, training_accuracy : 0.025 training_loss : 0.6362193036050966 val_accuracy : 0.013333333333333334 val_loss : 0.6588625006221398
# Epoch 119, training_accuracy : 0.025 training_loss : 0.6361417700279997 val_accuracy : 0.013333333333333334 val_loss : 0.6590497244047898
# Epoch 120, training_accuracy : 0.02625 training_loss : 0.6360665833267745 val_accuracy : 0.013333333333333334 val_loss : 0.6592349516508815
# Epoch 121, training_accuracy : 0.02625 training_loss : 0.6359935475631575 val_accuracy : 0.013333333333333334 val_loss : 0.6594185135213344
# Epoch 122, training_accuracy : 0.025 training_loss : 0.6359224463850629 val_accuracy : 0.013333333333333334 val_loss : 0.6596006573480367
# Epoch 123, training_accuracy : 0.02625 training_loss : 0.6358530563918245 val_accuracy : 0.013333333333333334 val_loss : 0.6597815446991772
# Epoch 124, training_accuracy : 0.02625 training_loss : 0.6357851615395539 val_accuracy : 0.013333333333333334 val_loss : 0.6599612523301799
# Epoch 125, training_accuracy : 0.02625 training_loss : 0.6357185673440799 val_accuracy : 0.013333333333333334 val_loss : 0.6601397756983787
# Epoch 126, training_accuracy : 0.02625 training_loss : 0.6356531134467704 val_accuracy : 0.013333333333333334 val_loss : 0.6603170345913445
# Epoch 127, training_accuracy : 0.02625 training_loss : 0.6355886830803771 val_accuracy : 0.013333333333333334 val_loss : 0.6604928804126854
# Epoch 128, training_accuracy : 0.02625 training_loss : 0.6355252081854839 val_accuracy : 0.013333333333333334 val_loss : 0.6606671047987812
# Epoch 129, training_accuracy : 0.02625 training_loss : 0.635462669448679 val_accuracy : 0.013333333333333334 val_loss : 0.6608394494629404
# Epoch 130, training_accuracy : 0.02625 training_loss : 0.6354010913385132 val_accuracy : 0.013333333333333334 val_loss : 0.6610096173655273
# Epoch 131, training_accuracy : 0.02625 training_loss : 0.6353405331352502 val_accuracy : 0.013333333333333334 val_loss : 0.6611772853418973
# Epoch 132, training_accuracy : 0.02625 training_loss : 0.635281077696556 val_accuracy : 0.013333333333333334 val_loss : 0.6613421180950141
# Epoch 133, training_accuracy : 0.0275 training_loss : 0.6352228199960771 val_accuracy : 0.013333333333333334 val_loss : 0.6615037830298831
# Epoch 134, training_accuracy : 0.0275 training_loss : 0.6351658572117953 val_accuracy : 0.013333333333333334 val_loss : 0.6616619649651099
# Epoch 135, training_accuracy : 0.02625 training_loss : 0.6351102814645992 val_accuracy : 0.013333333333333334 val_loss : 0.6618163795235231
# Epoch 136, training_accuracy : 0.02625 training_loss : 0.6350561755077028 val_accuracy : 0.013333333333333334 val_loss : 0.6619667840904515
# Epoch 137, training_accuracy : 0.02625 training_loss : 0.6350036110209331 val_accuracy : 0.013333333333333334 val_loss : 0.6621129855823286
# Epoch 138, training_accuracy : 0.025 training_loss : 0.6349526488040954 val_accuracy : 0.013333333333333334 val_loss : 0.6622548447314838
# Epoch 139, training_accuracy : 0.025 training_loss : 0.6349033400730596 val_accuracy : 0.013333333333333334 val_loss : 0.6623922770082028
# Epoch 140, training_accuracy : 0.025 training_loss : 0.6348557281447051 val_accuracy : 0.013333333333333334 val_loss : 0.6625252505853428
# Epoch 141, training_accuracy : 0.02375 training_loss : 0.6348098499563178 val_accuracy : 0.013333333333333334 val_loss : 0.6626537819017158
# Epoch 142, training_accuracy : 0.02375 training_loss : 0.6347657370432978 val_accuracy : 0.013333333333333334 val_loss : 0.6627779294405003
# Epoch 143, training_accuracy : 0.02375 training_loss : 0.6347234157738236 val_accuracy : 0.013333333333333334 val_loss : 0.662897786354097
# Epoch 144, training_accuracy : 0.02375 training_loss : 0.6346829068047852 val_accuracy : 0.013333333333333334 val_loss : 0.6630134725628506
# Epoch 145, training_accuracy : 0.02375 training_loss : 0.6346442238740905 val_accuracy : 0.013333333333333334 val_loss : 0.6631251269334065
# Epoch 146, training_accuracy : 0.02375 training_loss : 0.6346073721678277 val_accuracy : 0.013333333333333334 val_loss : 0.6632329000896016
# Epoch 147, training_accuracy : 0.02375 training_loss : 0.6345723465793044 val_accuracy : 0.013333333333333334 val_loss : 0.663336948309609
# Epoch 148, training_accuracy : 0.02375 training_loss : 0.634539130196652 val_accuracy : 0.013333333333333334 val_loss : 0.6634374288136585
# Epoch 149, training_accuracy : 0.02375 training_loss : 0.6345076933122176 val_accuracy : 0.013333333333333334 val_loss : 0.6635344965605454
# Epoch 150, training_accuracy : 0.02375 training_loss : 0.634477993150874 val_accuracy : 0.013333333333333334 val_loss : 0.6636283024779085
# Epoch 151, training_accuracy : 0.0225 training_loss : 0.6344499743888006 val_accuracy : 0.013333333333333334 val_loss : 0.6637189928873277
# Epoch 152, training_accuracy : 0.0225 training_loss : 0.6344235704079536 val_accuracy : 0.013333333333333334 val_loss : 0.6638067097808139
# Epoch 153, training_accuracy : 0.0225 training_loss : 0.6343987051307922 val_accuracy : 0.013333333333333334 val_loss : 0.6638915915744784
# Epoch 154, training_accuracy : 0.0225 training_loss : 0.6343752952208273 val_accuracy : 0.013333333333333334 val_loss : 0.6639737740019988
# Epoch 155, training_accuracy : 0.0225 training_loss : 0.6343532524208726 val_accuracy : 0.013333333333333334 val_loss : 0.6640533908939038
# Epoch 156, training_accuracy : 0.02 training_loss : 0.6343324858247414 val_accuracy : 0.013333333333333334 val_loss : 0.6641305746910172
# Epoch 157, training_accuracy : 0.02 training_loss : 0.6343129039259684 val_accuracy : 0.013333333333333334 val_loss : 0.6642054566368165
# Epoch 158, training_accuracy : 0.02 training_loss : 0.634294416344001 val_accuracy : 0.013333333333333334 val_loss : 0.66427816666789
# Epoch 159, training_accuracy : 0.02 training_loss : 0.6342769351823278 val_accuracy : 0.013333333333333334 val_loss : 0.6643488330677624
# Epoch 160, training_accuracy : 0.01875 training_loss : 0.6342603760167175 val_accuracy : 0.013333333333333334 val_loss : 0.6644175819690002
# Epoch 161, training_accuracy : 0.01875 training_loss : 0.6342446585423519 val_accuracy : 0.013333333333333334 val_loss : 0.6644845367880204
# Epoch 162, training_accuracy : 0.01875 training_loss : 0.6342297069263045 val_accuracy : 0.013333333333333334 val_loss : 0.664549817664122
# Epoch 163, training_accuracy : 0.01875 training_loss : 0.6342154499191694 val_accuracy : 0.013333333333333334 val_loss : 0.6646135409557995
# Epoch 164, training_accuracy : 0.01875 training_loss : 0.6342018207793059 val_accuracy : 0.013333333333333334 val_loss : 0.6646758188283786
# Epoch 165, training_accuracy : 0.01875 training_loss : 0.6341887570582159 val_accuracy : 0.013333333333333334 val_loss : 0.6647367589503996
# Epoch 166, training_accuracy : 0.01875 training_loss : 0.6341762002883048 val_accuracy : 0.013333333333333334 val_loss : 0.6647964643032932
# Epoch 167, training_accuracy : 0.01875 training_loss : 0.6341640956060632 val_accuracy : 0.013333333333333334 val_loss : 0.6648550330999008
# Epoch 168, training_accuracy : 0.01875 training_loss : 0.6341523913360073 val_accuracy : 0.013333333333333334 val_loss : 0.6649125588019472
# Epoch 169, training_accuracy : 0.01875 training_loss : 0.6341410385537188 val_accuracy : 0.013333333333333334 val_loss : 0.6649691302237748
# Epoch 170, training_accuracy : 0.02 training_loss : 0.6341299906404556 val_accuracy : 0.013333333333333334 val_loss : 0.6650248317089416
# Epoch 171, training_accuracy : 0.02 training_loss : 0.6341192028370617 val_accuracy : 0.013333333333333334 val_loss : 0.6650797433668293
# Epoch 172, training_accuracy : 0.02 training_loss : 0.6341086318011296 val_accuracy : 0.013333333333333334 val_loss : 0.6651339413577555
# Epoch 173, training_accuracy : 0.02 training_loss : 0.6340982351684455 val_accuracy : 0.013333333333333334 val_loss : 0.6651874982168717
# Epoch 174, training_accuracy : 0.02 training_loss : 0.6340879711175641 val_accuracy : 0.013333333333333334 val_loss : 0.6652404832089807
# Epoch 175, training_accuracy : 0.0225 training_loss : 0.6340777979345903 val_accuracy : 0.013333333333333334 val_loss : 0.6652929627082976
# Epoch 176, training_accuracy : 0.0225 training_loss : 0.6340676735740014 val_accuracy : 0.013333333333333334 val_loss : 0.6653450005989248
# Epoch 177, training_accuracy : 0.0225 training_loss : 0.6340575552102318 val_accuracy : 0.013333333333333334 val_loss : 0.6653966586933798
# Epoch 178, training_accuracy : 0.02375 training_loss : 0.6340473987739513 val_accuracy : 0.013333333333333334 val_loss : 0.6654479971679712
# Epoch 179, training_accuracy : 0.02375 training_loss : 0.634037158466142 val_accuracy : 0.013333333333333334 val_loss : 0.6654990750150505
# Epoch 180, training_accuracy : 0.02375 training_loss : 0.6340267862425479 val_accuracy : 0.013333333333333334 val_loss : 0.6655499505133218
# Epoch 181, training_accuracy : 0.02375 training_loss : 0.6340162312603737 val_accuracy : 0.013333333333333334 val_loss : 0.6656006817183747
# Epoch 182, training_accuracy : 0.02375 training_loss : 0.6340054392786925 val_accuracy : 0.013333333333333334 val_loss : 0.6656513269765155
# Epoch 183, training_accuracy : 0.02375 training_loss : 0.6339943520037324 val_accuracy : 0.013333333333333334 val_loss : 0.6657019454657416
# Epoch 184, training_accuracy : 0.02375 training_loss : 0.6339829063700754 val_accuracy : 0.013333333333333334 val_loss : 0.6657525977683606
# Epoch 185, training_accuracy : 0.02375 training_loss : 0.6339710337493283 val_accuracy : 0.013333333333333334 val_loss : 0.6658033464801758
# Epoch 186, training_accuracy : 0.02375 training_loss : 0.6339586590789332 val_accuracy : 0.013333333333333334 val_loss : 0.665854256861354
# Epoch 187, training_accuracy : 0.02375 training_loss : 0.6339456999062231 val_accuracy : 0.013333333333333334 val_loss : 0.6659053975336797
# Epoch 188, training_accuracy : 0.02375 training_loss : 0.6339320653470921 val_accuracy : 0.013333333333333334 val_loss : 0.6659568412278369
# Epoch 189, training_accuracy : 0.02375 training_loss : 0.6339176549657761 val_accuracy : 0.013333333333333334 val_loss : 0.6660086655819413
# Epoch 190, training_accuracy : 0.02375 training_loss : 0.6339023575935953 val_accuracy : 0.013333333333333334 val_loss : 0.6660609539882222
# Epoch 191, training_accuracy : 0.02375 training_loss : 0.6338860501220193 val_accuracy : 0.013333333333333334 val_loss : 0.666113796477431
# Epoch 192, training_accuracy : 0.0225 training_loss : 0.6338685963318123 val_accuracy : 0.013333333333333334 val_loss : 0.6661672906186168
# Epoch 193, training_accuracy : 0.02125 training_loss : 0.6338498458586189 val_accuracy : 0.006666666666666667 val_loss : 0.6662215423932434
# Epoch 194, training_accuracy : 0.02125 training_loss : 0.6338296334506991 val_accuracy : 0.006666666666666667 val_loss : 0.6662766669740443
# Epoch 195, training_accuracy : 0.02125 training_loss : 0.6338077787514841 val_accuracy : 0.006666666666666667 val_loss : 0.666332789296431
# Epoch 196, training_accuracy : 0.02125 training_loss : 0.6337840869429009 val_accuracy : 0.006666666666666667 val_loss : 0.6663900442485445
# Epoch 197, training_accuracy : 0.02 training_loss : 0.6337583507175836 val_accuracy : 0.006666666666666667 val_loss : 0.6664485762193877
# Epoch 198, training_accuracy : 0.02 training_loss : 0.6337303542054701 val_accuracy : 0.006666666666666667 val_loss : 0.666508537627977
# Epoch 199, training_accuracy : 0.02 training_loss : 0.6336998796460445 val_accuracy : 0.006666666666666667 val_loss : 0.6665700859089809
# Epoch 200, training_accuracy : 0.02 training_loss : 0.6336667177310289 val_accuracy : 0.006666666666666667 val_loss : 0.6666333782609506
# Epoch 201, training_accuracy : 0.02 training_loss : 0.6336306825648211 val_accuracy : 0.006666666666666667 val_loss : 0.6666985633012156
# Epoch 202, training_accuracy : 0.02 training_loss : 0.6335916319718717 val_accuracy : 0.006666666666666667 val_loss : 0.6667657686814658
# Epoch 203, training_accuracy : 0.02 training_loss : 0.6335494932417061 val_accuracy : 0.006666666666666667 val_loss : 0.6668350838160743
# Epoch 204, training_accuracy : 0.02 training_loss : 0.6335042931525751 val_accuracy : 0.006666666666666667 val_loss : 0.6669065373360271
# Epoch 205, training_accuracy : 0.02125 training_loss : 0.6334561891612501 val_accuracy : 0.006666666666666667 val_loss : 0.6669800699126754
# Epoch 206, training_accuracy : 0.02125 training_loss : 0.6334054961913705 val_accuracy : 0.006666666666666667 val_loss : 0.6670555048467038
# Epoch 207, training_accuracy : 0.02125 training_loss : 0.6333527012205645 val_accuracy : 0.006666666666666667 val_loss : 0.6671325211972694
# Epoch 208, training_accuracy : 0.02125 training_loss : 0.6332984571709306 val_accuracy : 0.006666666666666667 val_loss : 0.667210636667632
# Epoch 209, training_accuracy : 0.0225 training_loss : 0.6332435499555176 val_accuracy : 0.006666666666666667 val_loss : 0.6672892088004428
# Epoch 210, training_accuracy : 0.0225 training_loss : 0.6331888386163491 val_accuracy : 0.006666666666666667 val_loss : 0.667367461769241
# Epoch 211, training_accuracy : 0.02125 training_loss : 0.6331351769999672 val_accuracy : 0.006666666666666667 val_loss : 0.6674445411946831
# Epoch 212, training_accuracy : 0.02125 training_loss : 0.6330833328254134 val_accuracy : 0.006666666666666667 val_loss : 0.6675195916107148
# Epoch 213, training_accuracy : 0.02125 training_loss : 0.6330339222244673 val_accuracy : 0.006666666666666667 val_loss : 0.6675918432134205
# Epoch 214, training_accuracy : 0.0225 training_loss : 0.6329873730907445 val_accuracy : 0.006666666666666667 val_loss : 0.6676606901349086
# Epoch 215, training_accuracy : 0.02375 training_loss : 0.6329439210237107 val_accuracy : 0.006666666666666667 val_loss : 0.6677257441996988
# Epoch 216, training_accuracy : 0.025 training_loss : 0.6329036320670517 val_accuracy : 0.006666666666666667 val_loss : 0.6677868553390988
# Epoch 217, training_accuracy : 0.025 training_loss : 0.6328664409303782 val_accuracy : 0.006666666666666667 val_loss : 0.6678440991828688
# Epoch 218, training_accuracy : 0.025 training_loss : 0.632832193076139 val_accuracy : 0.006666666666666667 val_loss : 0.6678977398851025
# Epoch 219, training_accuracy : 0.025 training_loss : 0.6328006823141654 val_accuracy : 0.006666666666666667 val_loss : 0.6679481797001333
# Epoch 220, training_accuracy : 0.02375 training_loss : 0.6327716798243381 val_accuracy : 0.006666666666666667 val_loss : 0.6679959062591219
# Epoch 221, training_accuracy : 0.02375 training_loss : 0.6327449539790266 val_accuracy : 0.006666666666666667 val_loss : 0.6680414454662844
# Epoch 222, training_accuracy : 0.02375 training_loss : 0.632720282312821 val_accuracy : 0.006666666666666667 val_loss : 0.6680853242394231
# Epoch 223, training_accuracy : 0.02375 training_loss : 0.6326974576842805 val_accuracy : 0.006666666666666667 val_loss : 0.6681280442024745
# Epoch 224, training_accuracy : 0.02375 training_loss : 0.6326762905922508 val_accuracy : 0.006666666666666667 val_loss : 0.6681700653968655
# Epoch 225, training_accuracy : 0.02375 training_loss : 0.6326566091956513 val_accuracy : 0.006666666666666667 val_loss : 0.6682117980778824
# Epoch 226, training_accuracy : 0.02375 training_loss : 0.6326382581190328 val_accuracy : 0.006666666666666667 val_loss : 0.6682536004201409
# Epoch 227, training_accuracy : 0.02375 training_loss : 0.6326210967332089 val_accuracy : 0.006666666666666667 val_loss : 0.6682957801556976
# Epoch 228, training_accuracy : 0.025 training_loss : 0.632604997314252 val_accuracy : 0.006666666666666667 val_loss : 0.6683385985591964
# Epoch 229, training_accuracy : 0.025 training_loss : 0.6325898432945758 val_accuracy : 0.006666666666666667 val_loss : 0.6683822756174199
# Epoch 230, training_accuracy : 0.025 training_loss : 0.6325755277031383 val_accuracy : 0.006666666666666667 val_loss : 0.6684269955933664
# Epoch 231, training_accuracy : 0.025 training_loss : 0.6325619518246962 val_accuracy : 0.006666666666666667 val_loss : 0.6684729124871599
# Epoch 232, training_accuracy : 0.025 training_loss : 0.6325490240724605 val_accuracy : 0.006666666666666667 val_loss : 0.6685201551065917
# Epoch 233, training_accuracy : 0.025 training_loss : 0.6325366590521074 val_accuracy : 0.006666666666666667 val_loss : 0.6685688316015249
# Epoch 234, training_accuracy : 0.025 training_loss : 0.632524776789397 val_accuracy : 0.006666666666666667 val_loss : 0.6686190334051516
# Epoch 235, training_accuracy : 0.025 training_loss : 0.6325133020940595 val_accuracy : 0.006666666666666667 val_loss : 0.6686708385767061
# Epoch 236, training_accuracy : 0.025 training_loss : 0.6325021640357054 val_accuracy : 0.006666666666666667 val_loss : 0.6687243145673888
# Epoch 237, training_accuracy : 0.025 training_loss : 0.632491295511866 val_accuracy : 0.006666666666666667 val_loss : 0.668779520443215
# Epoch 238, training_accuracy : 0.025 training_loss : 0.6324806328927266 val_accuracy : 0.006666666666666667 val_loss : 0.6688365086019185
# Epoch 239, training_accuracy : 0.025 training_loss : 0.6324701157313136 val_accuracy : 0.006666666666666667 val_loss : 0.6688953260200239
# Epoch 240, training_accuracy : 0.025 training_loss : 0.6324596865313934 val_accuracy : 0.006666666666666667 val_loss : 0.6689560150635923
# Epoch 241, training_accuracy : 0.025 training_loss : 0.6324492905682224 val_accuracy : 0.006666666666666667 val_loss : 0.6690186138934763
# Epoch 242, training_accuracy : 0.025 training_loss : 0.6324388757593774 val_accuracy : 0.006666666666666667 val_loss : 0.6690831564942885
# Epoch 243, training_accuracy : 0.025 training_loss : 0.63242839258414 val_accuracy : 0.006666666666666667 val_loss : 0.6691496723562315
# Epoch 244, training_accuracy : 0.025 training_loss : 0.6324177940505281 val_accuracy : 0.006666666666666667 val_loss : 0.6692181858409614
# Epoch 245, training_accuracy : 0.025 training_loss : 0.6324070357087745 val_accuracy : 0.006666666666666667 val_loss : 0.6692887152668999
# Epoch 246, training_accuracy : 0.025 training_loss : 0.632396075709183 val_accuracy : 0.006666666666666667 val_loss : 0.6693612717560491
# Epoch 247, training_accuracy : 0.025 training_loss : 0.6323848749006553 val_accuracy : 0.006666666666666667 val_loss : 0.6694358578931815
# Epoch 248, training_accuracy : 0.025 training_loss : 0.6323733969641208 val_accuracy : 0.006666666666666667 val_loss : 0.6695124662589006
# Epoch 249, training_accuracy : 0.025 training_loss : 0.6323616085725662 val_accuracy : 0.006666666666666667 val_loss : 0.6695910779096472
# Epoch 250, training_accuracy : 0.025 training_loss : 0.6323494795668249 val_accuracy : 0.006666666666666667 val_loss : 0.669671660889065
# Epoch 251, training_accuracy : 0.025 training_loss : 0.6323369831338611 val_accuracy : 0.006666666666666667 val_loss : 0.6697541688645663
# Epoch 252, training_accuracy : 0.025 training_loss : 0.63232409597255 val_accuracy : 0.006666666666666667 val_loss : 0.6698385399885914
# Epoch 253, training_accuracy : 0.025 training_loss : 0.632310798431149 val_accuracy : 0.006666666666666667 val_loss : 0.6699246960838653
# Epoch 254, training_accuracy : 0.025 training_loss : 0.6322970746012546 val_accuracy : 0.006666666666666667 val_loss : 0.6700125422442572
# Epoch 255, training_accuracy : 0.025 training_loss : 0.6322829123552934 val_accuracy : 0.006666666666666667 val_loss : 0.6701019669265076
# Epoch 256, training_accuracy : 0.025 training_loss : 0.6322683033184083 val_accuracy : 0.006666666666666667 val_loss : 0.6701928425831282
# Epoch 257, training_accuracy : 0.025 training_loss : 0.6322532427709726 val_accuracy : 0.006666666666666667 val_loss : 0.6702850268544266
# Epoch 258, training_accuracy : 0.025 training_loss : 0.6322377294841661 val_accuracy : 0.006666666666666667 val_loss : 0.6703783643005249
# Epoch 259, training_accuracy : 0.025 training_loss : 0.6322217654974506 val_accuracy : 0.006666666666666667 val_loss : 0.6704726886161693
# Epoch 260, training_accuracy : 0.025 training_loss : 0.6322053558523971 val_accuracy : 0.006666666666666667 val_loss : 0.6705678252363694
# Epoch 261, training_accuracy : 0.025 training_loss : 0.6321885083012952 val_accuracy : 0.006666666666666667 val_loss : 0.6706635942136239
# Epoch 262, training_accuracy : 0.025 training_loss : 0.6321712330105814 val_accuracy : 0.006666666666666667 val_loss : 0.6707598132309512
# Epoch 263, training_accuracy : 0.025 training_loss : 0.6321535422780833 val_accuracy : 0.006666666666666667 val_loss : 0.6708563006107626
# Epoch 264, training_accuracy : 0.025 training_loss : 0.6321354502795309 val_accuracy : 0.006666666666666667 val_loss : 0.6709528781877534
# Epoch 265, training_accuracy : 0.02625 training_loss : 0.632116972854321 val_accuracy : 0.006666666666666667 val_loss : 0.6710493739325177
# Epoch 266, training_accuracy : 0.025 training_loss : 0.6320981273340459 val_accuracy : 0.006666666666666667 val_loss : 0.6711456242384553
# Epoch 267, training_accuracy : 0.025 training_loss : 0.6320789324109264 val_accuracy : 0.006666666666666667 val_loss : 0.6712414758139627
# Epoch 268, training_accuracy : 0.02375 training_loss : 0.6320594080378477 val_accuracy : 0.006666666666666667 val_loss : 0.6713367871513198
# Epoch 269, training_accuracy : 0.02375 training_loss : 0.6320395753481377 val_accuracy : 0.006666666666666667 val_loss : 0.6714314295700815
# Epoch 270, training_accuracy : 0.02375 training_loss : 0.6320194565816056 val_accuracy : 0.006666666666666667 val_loss : 0.6715252878541623
# Epoch 271, training_accuracy : 0.0225 training_loss : 0.6319990750040136 val_accuracy : 0.006666666666666667 val_loss : 0.6716182605172497
# Epoch 272, training_accuracy : 0.0225 training_loss : 0.6319784548094901 val_accuracy : 0.006666666666666667 val_loss : 0.6717102597406295
# Epoch 273, training_accuracy : 0.02125 training_loss : 0.6319576209991035 val_accuracy : 0.006666666666666667 val_loss : 0.6718012110316699
# Epoch 274, training_accuracy : 0.02125 training_loss : 0.6319365992331359 val_accuracy : 0.006666666666666667 val_loss : 0.6718910526512378
# Epoch 275, training_accuracy : 0.02125 training_loss : 0.6319154156589627 val_accuracy : 0.006666666666666667 val_loss : 0.6719797348555258
# Epoch 276, training_accuracy : 0.0225 training_loss : 0.6318940967202047 val_accuracy : 0.006666666666666667 val_loss : 0.6720672189935363
# Epoch 277, training_accuracy : 0.0225 training_loss : 0.6318726689556141 val_accuracy : 0.006666666666666667 val_loss : 0.6721534764969758
# Epoch 278, training_accuracy : 0.0225 training_loss : 0.631851158797556 val_accuracy : 0.006666666666666667 val_loss : 0.6722384877954657
# Epoch 279, training_accuracy : 0.0225 training_loss : 0.6318295923799707 val_accuracy : 0.006666666666666667 val_loss : 0.6723222411873413
# Epoch 280, training_accuracy : 0.02125 training_loss : 0.6318079953643737 val_accuracy : 0.006666666666666667 val_loss : 0.672404731694884
# Epoch 281, training_accuracy : 0.02125 training_loss : 0.6317863927901144 val_accuracy : 0.006666666666666667 val_loss : 0.6724859599323888
# Epoch 282, training_accuracy : 0.02125 training_loss : 0.6317648089521274 val_accuracy : 0.006666666666666667 val_loss : 0.6725659310152594
# Epoch 283, training_accuracy : 0.02125 training_loss : 0.631743267306313 val_accuracy : 0.006666666666666667 val_loss : 0.6726446535376361
# Epoch 284, training_accuracy : 0.02125 training_loss : 0.6317217904000004 val_accuracy : 0.006666666666666667 val_loss : 0.6727221386441298
# Epoch 285, training_accuracy : 0.02125 training_loss : 0.6317003998228489 val_accuracy : 0.006666666666666667 val_loss : 0.672798399217666
# Epoch 286, training_accuracy : 0.02125 training_loss : 0.6316791161725027 val_accuracy : 0.006666666666666667 val_loss : 0.6728734492001107
# Epoch 287, training_accuracy : 0.02125 training_loss : 0.6316579590291653 val_accuracy : 0.006666666666666667 val_loss : 0.6729473030556579
# Epoch 288, training_accuracy : 0.02125 training_loss : 0.6316369469338933 val_accuracy : 0.006666666666666667 val_loss : 0.6730199753795201
# Epoch 289, training_accuracy : 0.02125 training_loss : 0.6316160973667364 val_accuracy : 0.006666666666666667 val_loss : 0.6730914806470767
# Epoch 290, training_accuracy : 0.02125 training_loss : 0.631595426722312 val_accuracy : 0.006666666666666667 val_loss : 0.6731618330921307
# Epoch 291, training_accuracy : 0.02125 training_loss : 0.6315749502820196 val_accuracy : 0.006666666666666667 val_loss : 0.6732310466978243
# Epoch 292, training_accuracy : 0.02125 training_loss : 0.6315546821834153 val_accuracy : 0.006666666666666667 val_loss : 0.673299135280509
# Epoch 293, training_accuracy : 0.02125 training_loss : 0.631534635388305 val_accuracy : 0.006666666666666667 val_loss : 0.6733661126454376
# Epoch 294, training_accuracy : 0.02125 training_loss : 0.6315148216517045 val_accuracy : 0.006666666666666667 val_loss : 0.6734319927933928
# Epoch 295, training_accuracy : 0.02125 training_loss : 0.631495251494089 val_accuracy : 0.006666666666666667 val_loss : 0.6734967901590048
# Epoch 296, training_accuracy : 0.02125 training_loss : 0.6314759341792664 val_accuracy : 0.006666666666666667 val_loss : 0.6735605198639921
# Epoch 297, training_accuracy : 0.02125 training_loss : 0.631456877699887 val_accuracy : 0.006666666666666667 val_loss : 0.6736231979716233
# Epoch 298, training_accuracy : 0.02125 training_loss : 0.6314380887722123 val_accuracy : 0.006666666666666667 val_loss : 0.673684841731854
# Epoch 299, training_accuracy : 0.02125 training_loss : 0.631419572841167 val_accuracy : 0.006666666666666667 val_loss : 0.6737454698095989
# Epoch 300, training_accuracy : 0.0225 training_loss : 0.6314013340963149 val_accuracy : 0.006666666666666667 val_loss : 0.6738051024913085
# Epoch 301, training_accuracy : 0.0225 training_loss : 0.6313833754988473 val_accuracy : 0.006666666666666667 val_loss : 0.6738637618672253
# Epoch 302, training_accuracy : 0.02125 training_loss : 0.6313656988193656 val_accuracy : 0.006666666666666667 val_loss : 0.6739214719884704
# Epoch 303, training_accuracy : 0.02125 training_loss : 0.631348304685934 val_accuracy : 0.006666666666666667 val_loss : 0.673978258999369
# Epoch 304, training_accuracy : 0.02125 training_loss : 0.6313311926417032 val_accuracy : 0.006666666666666667 val_loss : 0.6740341512462614
# Epoch 305, training_accuracy : 0.02125 training_loss : 0.6313143612112729 val_accuracy : 0.006666666666666667 val_loss : 0.674089179364537
# Epoch 306, training_accuracy : 0.02125 training_loss : 0.6312978079749576 val_accuracy : 0.006666666666666667 val_loss : 0.6741433763457596
# Epoch 307, training_accuracy : 0.02 training_loss : 0.6312815296501216 val_accuracy : 0.006666666666666667 val_loss : 0.6741967775866838
# Epoch 308, training_accuracy : 0.02 training_loss : 0.631265522178808 val_accuracy : 0.006666666666666667 val_loss : 0.6742494209216758
# Epoch 309, training_accuracy : 0.02 training_loss : 0.6312497808209904 val_accuracy : 0.006666666666666667 val_loss : 0.6743013466396472
# Epoch 310, training_accuracy : 0.02 training_loss : 0.6312343002528741 val_accuracy : 0.006666666666666667 val_loss : 0.6743525974860775
# Epoch 311, training_accuracy : 0.02125 training_loss : 0.631219074669806 val_accuracy : 0.006666666666666667 val_loss : 0.6744032186501274
# Epoch 312, training_accuracy : 0.02125 training_loss : 0.6312040978934049 val_accuracy : 0.006666666666666667 val_loss : 0.6744532577362047
# Epoch 313, training_accuracy : 0.0225 training_loss : 0.6311893634827231 val_accuracy : 0.006666666666666667 val_loss : 0.6745027647186784
# Epoch 314, training_accuracy : 0.02375 training_loss : 0.6311748648492039 val_accuracy : 0.006666666666666667 val_loss : 0.6745517918777767
# Epoch 315, training_accuracy : 0.0225 training_loss : 0.6311605953753614 val_accuracy : 0.006666666666666667 val_loss : 0.6746003937140234
# Epoch 316, training_accuracy : 0.0225 training_loss : 0.6311465485370377 val_accuracy : 0.006666666666666667 val_loss : 0.6746486268379149
# Epoch 317, training_accuracy : 0.0225 training_loss : 0.6311327180291231 val_accuracy : 0.006666666666666667 val_loss : 0.6746965498309204
# Epoch 318, training_accuracy : 0.0225 training_loss : 0.6311190978944983 val_accuracy : 0.006666666666666667 val_loss : 0.6747442230733296
# Epoch 319, training_accuracy : 0.0225 training_loss : 0.63110568265585 val_accuracy : 0.006666666666666667 val_loss : 0.6747917085339923
# Epoch 320, training_accuracy : 0.02125 training_loss : 0.6310924674497496 val_accuracy : 0.013333333333333334 val_loss : 0.6748390695166723
# Epoch 321, training_accuracy : 0.02125 training_loss : 0.6310794481621115 val_accuracy : 0.013333333333333334 val_loss : 0.6748863703575833
# Epoch 322, training_accuracy : 0.02125 training_loss : 0.6310666215637467 val_accuracy : 0.013333333333333334 val_loss : 0.6749336760688109
# Epoch 323, training_accuracy : 0.02125 training_loss : 0.6310539854441743 val_accuracy : 0.013333333333333334 val_loss : 0.6749810519227925
# Epoch 324, training_accuracy : 0.02125 training_loss : 0.6310415387413097 val_accuracy : 0.013333333333333334 val_loss : 0.675028562974
# Epoch 325, training_accuracy : 0.02125 training_loss : 0.6310292816638641 val_accuracy : 0.013333333333333334 val_loss : 0.6750762735154843
# Epoch 326, training_accuracy : 0.02125 training_loss : 0.6310172158025229 val_accuracy : 0.013333333333333334 val_loss : 0.6751242464701853
# Epoch 327, training_accuracy : 0.02125 training_loss : 0.6310053442250684 val_accuracy : 0.013333333333333334 val_loss : 0.675172542719968
# Epoch 328, training_accuracy : 0.02125 training_loss : 0.630993671549776 val_accuracy : 0.013333333333333334 val_loss : 0.6752212203793121
# Epoch 329, training_accuracy : 0.02125 training_loss : 0.6309822039905193 val_accuracy : 0.013333333333333334 val_loss : 0.6752703340254487
# Epoch 330, training_accuracy : 0.02125 training_loss : 0.6309709493664382 val_accuracy : 0.013333333333333334 val_loss : 0.6753199339024955
# Epoch 331, training_accuracy : 0.02125 training_loss : 0.6309599170685878 val_accuracy : 0.013333333333333334 val_loss : 0.6753700651235576
# Epoch 332, training_accuracy : 0.02125 training_loss : 0.6309491179760751 val_accuracy : 0.013333333333333334 val_loss : 0.6754207669014912
# Epoch 333, training_accuracy : 0.02125 training_loss : 0.6309385643147859 val_accuracy : 0.013333333333333334 val_loss : 0.67547207184559
# Epoch 334, training_accuracy : 0.02125 training_loss : 0.6309282694532112 val_accuracy : 0.013333333333333334 val_loss : 0.675524005367034
# Epoch 335, training_accuracy : 0.02125 training_loss : 0.6309182476320055 val_accuracy : 0.013333333333333334 val_loss : 0.6755765852397903
# Epoch 336, training_accuracy : 0.02125 training_loss : 0.6309085136270608 val_accuracy : 0.013333333333333334 val_loss : 0.6756298213646729
# Epoch 337, training_accuracy : 0.02125 training_loss : 0.6308990823496803 val_accuracy : 0.013333333333333334 val_loss : 0.675683715781609
# Epoch 338, training_accuracy : 0.02125 training_loss : 0.630889968392063 val_accuracy : 0.013333333333333334 val_loss : 0.6757382629680246
# Epoch 339, training_accuracy : 0.02125 training_loss : 0.6308811855311078 val_accuracy : 0.013333333333333334 val_loss : 0.6757934504492403
# Epoch 340, training_accuracy : 0.02125 training_loss : 0.6308727462083594 val_accuracy : 0.013333333333333334 val_loss : 0.6758492597300547
# Epoch 341, training_accuracy : 0.02125 training_loss : 0.6308646610079968 val_accuracy : 0.013333333333333334 val_loss : 0.6759056675360541
# Epoch 342, training_accuracy : 0.02125 training_loss : 0.6308569381576842 val_accuracy : 0.013333333333333334 val_loss : 0.6759626473302617
# Epoch 343, training_accuracy : 0.02125 training_loss : 0.6308495830782757 val_accuracy : 0.013333333333333334 val_loss : 0.6760201710474774
# Epoch 344, training_accuracy : 0.02125 training_loss : 0.6308425980074905 val_accuracy : 0.013333333333333334 val_loss : 0.676078210967912
# Epoch 345, training_accuracy : 0.02125 training_loss : 0.6308359817195432 val_accuracy : 0.013333333333333334 val_loss : 0.6761367416356479
# Epoch 346, training_accuracy : 0.02125 training_loss : 0.630829729357609 val_accuracy : 0.013333333333333334 val_loss : 0.6761957417186701
# Epoch 347, training_accuracy : 0.02125 training_loss : 0.6308238323891934 val_accuracy : 0.013333333333333334 val_loss : 0.6762551957066906
# Epoch 348, training_accuracy : 0.02125 training_loss : 0.6308182786868284 val_accuracy : 0.006666666666666667 val_loss : 0.6763150953514893
# ...
# Epoch 4870, training_accuracy : 0.05 training_loss : 0.6525697893363387 val_accuracy : 0.0 val_loss : 0.7927115021518386
# Epoch 4871, training_accuracy : 0.05 training_loss : 0.6526552857467428 val_accuracy : 0.0 val_loss : 0.797640022914632
# Epoch 4872, training_accuracy : 0.05 training_loss : 0.652474011390643 val_accuracy : 0.0 val_loss : 0.7946088095381052
# Epoch 4873, training_accuracy : 0.05125 training_loss : 0.652791388181819 val_accuracy : 0.0 val_loss : 0.7976304023919065
# Epoch 4874, training_accuracy : 0.05 training_loss : 0.6522867844106567 val_accuracy : 0.0 val_loss : 0.7947180346935891
# Epoch 4875, training_accuracy : 0.05125 training_loss : 0.6525582513831455 val_accuracy : 0.0 val_loss : 0.7930329659002887
# Epoch 4876, training_accuracy : 0.05 training_loss : 0.6527627420351284 val_accuracy : 0.0 val_loss : 0.8020255305483821
# Epoch 4877, training_accuracy : 0.04875 training_loss : 0.6536591621714021 val_accuracy : 0.0 val_loss : 0.8013885362516024
# Epoch 4878, training_accuracy : 0.05 training_loss : 0.6540033165321849 val_accuracy : 0.0 val_loss : 0.7993465484114899
# Epoch 4879, training_accuracy : 0.04875 training_loss : 0.6528925487977344 val_accuracy : 0.0 val_loss : 0.799316917252619
# Epoch 4880, training_accuracy : 0.05125 training_loss : 0.652694507096555 val_accuracy : 0.0 val_loss : 0.7978896484095304
# Epoch 4881, training_accuracy : 0.0525 training_loss : 0.6530640645742817 val_accuracy : 0.0 val_loss : 0.8039325034308132
# Epoch 4882, training_accuracy : 0.04875 training_loss : 0.6530962882820492 val_accuracy : 0.0 val_loss : 0.8020563112460937
# Epoch 4883, training_accuracy : 0.04875 training_loss : 0.6535208855943943 val_accuracy : 0.0 val_loss : 0.800853683263369
# Epoch 4884, training_accuracy : 0.04875 training_loss : 0.6532245446856153 val_accuracy : 0.0 val_loss : 0.8000014000177227
# Epoch 4885, training_accuracy : 0.0475 training_loss : 0.6530805219472078 val_accuracy : 0.0 val_loss : 0.8008221932972688
# Epoch 4886, training_accuracy : 0.05 training_loss : 0.6529361629291774 val_accuracy : 0.0 val_loss : 0.7998328946977826
# Epoch 4887, training_accuracy : 0.05 training_loss : 0.6526573798311943 val_accuracy : 0.0 val_loss : 0.7985007890010024
# Epoch 4888, training_accuracy : 0.05 training_loss : 0.6525254721785716 val_accuracy : 0.0 val_loss : 0.7964459364976751
# Epoch 4889, training_accuracy : 0.05125 training_loss : 0.6527636508788562 val_accuracy : 0.0 val_loss : 0.7977249092847682
# Epoch 4890, training_accuracy : 0.05 training_loss : 0.6524806966536947 val_accuracy : 0.0 val_loss : 0.7966202765803805
# Epoch 4891, training_accuracy : 0.05125 training_loss : 0.6523395820555586 val_accuracy : 0.0 val_loss : 0.795135585995462
# Epoch 4892, training_accuracy : 0.05125 training_loss : 0.6525472275064438 val_accuracy : 0.0 val_loss : 0.7988932062158027
# Epoch 4893, training_accuracy : 0.05 training_loss : 0.6526555590896657 val_accuracy : 0.0 val_loss : 0.7989935712283998
# Epoch 4894, training_accuracy : 0.05 training_loss : 0.653105177939645 val_accuracy : 0.0 val_loss : 0.7956097150368585
# Epoch 4895, training_accuracy : 0.05125 training_loss : 0.6526416396013773 val_accuracy : 0.0 val_loss : 0.8027013103802461
# Epoch 4896, training_accuracy : 0.04875 training_loss : 0.6531443860085665 val_accuracy : 0.0 val_loss : 0.8005498323811278
# Epoch 4897, training_accuracy : 0.05 training_loss : 0.6541799210138705 val_accuracy : 0.0 val_loss : 0.7997266424343409
# Epoch 4898, training_accuracy : 0.05 training_loss : 0.6531767701560782 val_accuracy : 0.0 val_loss : 0.7997110034084924
# Epoch 4899, training_accuracy : 0.04875 training_loss : 0.6528586714212123 val_accuracy : 0.0 val_loss : 0.7977342933633
# Epoch 4900, training_accuracy : 0.05125 training_loss : 0.6526236882878171 val_accuracy : 0.0 val_loss : 0.7968477009044149
# Epoch 4901, training_accuracy : 0.05125 training_loss : 0.6524970202237248 val_accuracy : 0.0 val_loss : 0.7954078216886931
# Epoch 4902, training_accuracy : 0.05125 training_loss : 0.6525316766176523 val_accuracy : 0.0 val_loss : 0.7949241217412581
# Epoch 4903, training_accuracy : 0.05125 training_loss : 0.6527062091104946 val_accuracy : 0.0 val_loss : 0.7963710630146438
# Epoch 4904, training_accuracy : 0.05125 training_loss : 0.6524929153559406 val_accuracy : 0.0 val_loss : 0.7957867425262659
# Epoch 4905, training_accuracy : 0.05125 training_loss : 0.6527698668012796 val_accuracy : 0.0 val_loss : 0.7969046716760553
# Epoch 4906, training_accuracy : 0.05 training_loss : 0.652886857488084 val_accuracy : 0.0 val_loss : 0.7951015880338297
# Epoch 4907, training_accuracy : 0.05 training_loss : 0.6531274439192372 val_accuracy : 0.0 val_loss : 0.8008769073305076
# Epoch 4908, training_accuracy : 0.05 training_loss : 0.6530037937081449 val_accuracy : 0.0 val_loss : 0.8008833471783352
# Epoch 4909, training_accuracy : 0.05125 training_loss : 0.6535604731127655 val_accuracy : 0.0 val_loss : 0.7959473900502829
# Epoch 4910, training_accuracy : 0.05125 training_loss : 0.652780638007428 val_accuracy : 0.0 val_loss : 0.801124085200463
# Epoch 4911, training_accuracy : 0.05 training_loss : 0.6531603488709894 val_accuracy : 0.0 val_loss : 0.8002403193076829
# Epoch 4912, training_accuracy : 0.05 training_loss : 0.6534740033233768 val_accuracy : 0.0 val_loss : 0.7976409687441118
# Epoch 4913, training_accuracy : 0.05125 training_loss : 0.6528764059216189 val_accuracy : 0.0 val_loss : 0.795754291951029
# Epoch 4914, training_accuracy : 0.05 training_loss : 0.6529671973135186 val_accuracy : 0.0 val_loss : 0.8055016871048634
# Epoch 4915, training_accuracy : 0.04875 training_loss : 0.6537885713787226 val_accuracy : 0.0 val_loss : 0.8039289777316034
# Epoch 4916, training_accuracy : 0.04875 training_loss : 0.654453507076806 val_accuracy : 0.0 val_loss : 0.8017847544643699
# Epoch 4917, training_accuracy : 0.04875 training_loss : 0.653635342796685 val_accuracy : 0.0 val_loss : 0.8028543046522123
# Epoch 4918, training_accuracy : 0.05125 training_loss : 0.653271858017547 val_accuracy : 0.0 val_loss : 0.8016547933708316
# Epoch 4919, training_accuracy : 0.05125 training_loss : 0.6531663399921028 val_accuracy : 0.0 val_loss : 0.800710033360785
# Epoch 4920, training_accuracy : 0.05 training_loss : 0.6530066863169924 val_accuracy : 0.0 val_loss : 0.7998999933477461
# Epoch 4921, training_accuracy : 0.05 training_loss : 0.6529688584808484 val_accuracy : 0.0 val_loss : 0.7978310054133513
# Epoch 4922, training_accuracy : 0.05 training_loss : 0.6530933991818795 val_accuracy : 0.0 val_loss : 0.7983203335549048
# Epoch 4923, training_accuracy : 0.05 training_loss : 0.6529389667954338 val_accuracy : 0.0 val_loss : 0.7956106704948399
# Epoch 4924, training_accuracy : 0.05125 training_loss : 0.6529963590623133 val_accuracy : 0.0 val_loss : 0.796148429960573
# Epoch 4925, training_accuracy : 0.05125 training_loss : 0.6526982395251508 val_accuracy : 0.0 val_loss : 0.7990372864579725
# Epoch 4926, training_accuracy : 0.05 training_loss : 0.6530951758715259 val_accuracy : 0.0 val_loss : 0.7965737425353702
# Epoch 4927, training_accuracy : 0.05125 training_loss : 0.6533791800296213 val_accuracy : 0.0 val_loss : 0.7999757416540284
# Epoch 4928, training_accuracy : 0.05 training_loss : 0.6531568422888668 val_accuracy : 0.0 val_loss : 0.7981183486503154
# Epoch 4929, training_accuracy : 0.05125 training_loss : 0.6532475364582297 val_accuracy : 0.0 val_loss : 0.8002042908785764
# Epoch 4930, training_accuracy : 0.05 training_loss : 0.65319971396025 val_accuracy : 0.0 val_loss : 0.796737407203119
# Epoch 4931, training_accuracy : 0.05125 training_loss : 0.6534509054465033 val_accuracy : 0.0 val_loss : 0.8044318856824846
# Epoch 4932, training_accuracy : 0.0475 training_loss : 0.6542808813611641 val_accuracy : 0.0 val_loss : 0.8020106446530226
# Epoch 4933, training_accuracy : 0.04875 training_loss : 0.654072890416555 val_accuracy : 0.0 val_loss : 0.80240629194755
# Epoch 4934, training_accuracy : 0.04875 training_loss : 0.6538001035089447 val_accuracy : 0.0 val_loss : 0.8025015824908955
# Epoch 4935, training_accuracy : 0.05125 training_loss : 0.6533368494376139 val_accuracy : 0.0 val_loss : 0.7984260478667047
# Epoch 4936, training_accuracy : 0.0525 training_loss : 0.6533354208235219 val_accuracy : 0.0 val_loss : 0.8032479527240067
# Epoch 4937, training_accuracy : 0.05125 training_loss : 0.6533005737027588 val_accuracy : 0.0 val_loss : 0.8009422248942014
# Epoch 4938, training_accuracy : 0.05 training_loss : 0.6538951970199218 val_accuracy : 0.0 val_loss : 0.8012782159843432
# Epoch 4939, training_accuracy : 0.05 training_loss : 0.6535135480732133 val_accuracy : 0.0 val_loss : 0.8006505242287442
# Epoch 4940, training_accuracy : 0.0475 training_loss : 0.6532927151772597 val_accuracy : 0.0 val_loss : 0.8007478686501133
# Epoch 4941, training_accuracy : 0.05125 training_loss : 0.6535503468459537 val_accuracy : 0.0 val_loss : 0.7979855553749896
# Epoch 4942, training_accuracy : 0.0525 training_loss : 0.6527991426048224 val_accuracy : 0.0 val_loss : 0.8019235472086186
# Epoch 4943, training_accuracy : 0.05 training_loss : 0.65346355360912 val_accuracy : 0.0 val_loss : 0.7996428715029555
# Epoch 4944, training_accuracy : 0.05125 training_loss : 0.6534855838955503 val_accuracy : 0.0 val_loss : 0.7972948305565926
# Epoch 4945, training_accuracy : 0.0525 training_loss : 0.653427042466989 val_accuracy : 0.0 val_loss : 0.7981850951520075
# Epoch 4946, training_accuracy : 0.05125 training_loss : 0.6529586796374786 val_accuracy : 0.0 val_loss : 0.7955963313336846
# Epoch 4947, training_accuracy : 0.05375 training_loss : 0.653821771441192 val_accuracy : 0.0 val_loss : 0.8032270086741353
# Epoch 4948, training_accuracy : 0.04875 training_loss : 0.6542618636595533 val_accuracy : 0.0 val_loss : 0.8036996819142904
# Epoch 4949, training_accuracy : 0.0475 training_loss : 0.6541945310800868 val_accuracy : 0.0 val_loss : 0.8032626306979969
# Epoch 4950, training_accuracy : 0.05125 training_loss : 0.6538270946228241 val_accuracy : 0.0 val_loss : 0.8028862783783294
# Epoch 4951, training_accuracy : 0.05 training_loss : 0.654083417161348 val_accuracy : 0.0 val_loss : 0.8002295364840827
# Epoch 4952, training_accuracy : 0.05 training_loss : 0.6534125841161865 val_accuracy : 0.0 val_loss : 0.7995855883590384
# Epoch 4953, training_accuracy : 0.05 training_loss : 0.6535689010939866 val_accuracy : 0.0 val_loss : 0.7984024188162209
# Epoch 4954, training_accuracy : 0.05125 training_loss : 0.6537193910934679 val_accuracy : 0.0 val_loss : 0.7981625117667552
# Epoch 4955, training_accuracy : 0.05125 training_loss : 0.6535402433773779 val_accuracy : 0.0 val_loss : 0.7969214569780575
# Epoch 4956, training_accuracy : 0.05 training_loss : 0.6534701876098685 val_accuracy : 0.0 val_loss : 0.8004149542559447
# Epoch 4957, training_accuracy : 0.05 training_loss : 0.6534021140043413 val_accuracy : 0.0 val_loss : 0.7982215812115158
# Epoch 4958, training_accuracy : 0.0525 training_loss : 0.6537591937297986 val_accuracy : 0.0 val_loss : 0.8026992566141998
# Epoch 4959, training_accuracy : 0.05125 training_loss : 0.6535860083398773 val_accuracy : 0.0 val_loss : 0.8012907226208567
# Epoch 4960, training_accuracy : 0.05125 training_loss : 0.6539553278885575 val_accuracy : 0.0 val_loss : 0.7975715455188078
# Epoch 4961, training_accuracy : 0.0525 training_loss : 0.6532583447247666 val_accuracy : 0.0 val_loss : 0.7990353879510689
# Epoch 4962, training_accuracy : 0.05125 training_loss : 0.6534122730012494 val_accuracy : 0.0 val_loss : 0.7966864858524988
# Epoch 4963, training_accuracy : 0.05125 training_loss : 0.653948039579638 val_accuracy : 0.0 val_loss : 0.8078869498639618
# Epoch 4964, training_accuracy : 0.05 training_loss : 0.6546370008169553 val_accuracy : 0.0 val_loss : 0.8057515366632352
# Epoch 4965, training_accuracy : 0.04875 training_loss : 0.6553159955457126 val_accuracy : 0.0 val_loss : 0.8034102585989834
# Epoch 4966, training_accuracy : 0.05 training_loss : 0.6543868518244657 val_accuracy : 0.0 val_loss : 0.8041905329278539
# Epoch 4967, training_accuracy : 0.05125 training_loss : 0.6539913138982725 val_accuracy : 0.0 val_loss : 0.803822405979658
# Epoch 4968, training_accuracy : 0.05125 training_loss : 0.6537353811790666 val_accuracy : 0.0 val_loss : 0.8028467623107267
# Epoch 4969, training_accuracy : 0.05125 training_loss : 0.6536383860644521 val_accuracy : 0.0 val_loss : 0.8019494237183274
# Epoch 4970, training_accuracy : 0.05125 training_loss : 0.6538487867963688 val_accuracy : 0.0 val_loss : 0.8007950095978096
# Epoch 4971, training_accuracy : 0.05125 training_loss : 0.6533358147005395 val_accuracy : 0.0 val_loss : 0.7987234948865329
# Epoch 4972, training_accuracy : 0.0525 training_loss : 0.6534067588292127 val_accuracy : 0.0 val_loss : 0.7996947083209949
# Epoch 4973, training_accuracy : 0.0525 training_loss : 0.6534501686043022 val_accuracy : 0.0 val_loss : 0.7988854329439598
# Epoch 4974, training_accuracy : 0.0525 training_loss : 0.6536889646516443 val_accuracy : 0.0 val_loss : 0.7990394253187094
# Epoch 4975, training_accuracy : 0.05125 training_loss : 0.6535741201264673 val_accuracy : 0.0 val_loss : 0.8061442568935869
# Epoch 4976, training_accuracy : 0.04875 training_loss : 0.6540285031883981 val_accuracy : 0.0 val_loss : 0.8061062013431785
# Epoch 4977, training_accuracy : 0.0525 training_loss : 0.6546570162302642 val_accuracy : 0.0 val_loss : 0.8025792411865331
# Epoch 4978, training_accuracy : 0.05125 training_loss : 0.6538602027794641 val_accuracy : 0.0 val_loss : 0.8029706780061144
# Epoch 4979, training_accuracy : 0.05 training_loss : 0.6541469804848633 val_accuracy : 0.0 val_loss : 0.80133694591383
# Epoch 4980, training_accuracy : 0.05125 training_loss : 0.6536967294023549 val_accuracy : 0.0 val_loss : 0.7989563623943614
# Epoch 4981, training_accuracy : 0.0525 training_loss : 0.6541080314116501 val_accuracy : 0.0 val_loss : 0.7998775103521341
# Epoch 4982, training_accuracy : 0.05125 training_loss : 0.6533701349584115 val_accuracy : 0.0 val_loss : 0.798358938534361
# Epoch 4983, training_accuracy : 0.05125 training_loss : 0.6538671927135173 val_accuracy : 0.0 val_loss : 0.7952763254049147
# Epoch 4984, training_accuracy : 0.05 training_loss : 0.6542616053438386 val_accuracy : 0.0 val_loss : 0.8067421538387546
# Epoch 4985, training_accuracy : 0.05 training_loss : 0.6547113764316991 val_accuracy : 0.0 val_loss : 0.8055688313128584
# Epoch 4986, training_accuracy : 0.05125 training_loss : 0.6554264226228262 val_accuracy : 0.0 val_loss : 0.803336834909377
# Epoch 4987, training_accuracy : 0.05 training_loss : 0.6544492825451274 val_accuracy : 0.0 val_loss : 0.8030539494301991
# Epoch 4988, training_accuracy : 0.05125 training_loss : 0.6544624752828451 val_accuracy : 0.0 val_loss : 0.8042741313393149
# Epoch 4989, training_accuracy : 0.05125 training_loss : 0.6541278762671351 val_accuracy : 0.0 val_loss : 0.8029716423542615
# Epoch 4990, training_accuracy : 0.05125 training_loss : 0.6537058119912267 val_accuracy : 0.0 val_loss : 0.8014161247520583
# Epoch 4991, training_accuracy : 0.05125 training_loss : 0.6542072171125338 val_accuracy : 0.0 val_loss : 0.8005890201000498
# Epoch 4992, training_accuracy : 0.05 training_loss : 0.653524544207902 val_accuracy : 0.0 val_loss : 0.7986033200970253
# Epoch 4993, training_accuracy : 0.05375 training_loss : 0.6536820014625774 val_accuracy : 0.0 val_loss : 0.7977756307568936
# Epoch 4994, training_accuracy : 0.0525 training_loss : 0.6537248568934703 val_accuracy : 0.0 val_loss : 0.8000553049817737
# Epoch 4995, training_accuracy : 0.05 training_loss : 0.6537484347733077 val_accuracy : 0.0 val_loss : 0.7973682654611819
# Epoch 4996, training_accuracy : 0.05125 training_loss : 0.6539116850657223 val_accuracy : 0.0 val_loss : 0.8041792258845245
# Epoch 4997, training_accuracy : 0.05 training_loss : 0.6539291083325607 val_accuracy : 0.0 val_loss : 0.8045552090967947
# Epoch 4998, training_accuracy : 0.05125 training_loss : 0.6546671281747978 val_accuracy : 0.0 val_loss : 0.800538652251255
# Epoch 4999, training_accuracy : 0.05125 training_loss : 0.6537583863708167 val_accuracy : 0.0 val_loss : 0.8001991624979817
